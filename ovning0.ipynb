# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Read in the data. This is a pretty ugly way of doing it, can you make a loop instead perhaps?
frames = {}
frames['A'] = pd.read_excel('Ovning_0_DATA.xlsx', sheet_name='A')
frames['B'] = pd.read_excel('Ovning_0_DATA.xlsx', sheet_name='B')
frames['C'] = pd.read_excel('Ovning_0_DATA.xlsx', sheet_name='C')
frames['D'] = pd.read_excel('Ovning_0_DATA.xlsx', sheet_name='D')
frames['E'] = pd.read_excel('Ovning_0_DATA.xlsx', sheet_name='E')

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))
sns.histplot(frames['A'], ax=axes[0])
sns.histplot(frames['B'], ax=axes[1])
sns.histplot(frames['C'], ax=axes[2])

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))
sns.scatterplot(frames['A'], ax=axes[0])
sns.scatterplot(frames['B'], ax=axes[1])
sns.scatterplot(frames['C'], ax=axes[2])

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))
sns.boxplot(frames['A'], ax=axes[0])
sns.boxplot(frames['B'], ax=axes[1])
sns.boxplot(frames['C'], ax=axes[2])

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12,3))
sns.violinplot(frames['A'], ax=axes[0])
sns.violinplot(frames['B'], ax=axes[1])
sns.violinplot(frames['C'], ax=axes[2])

plt.tight_layout()

# %%
df = pd.concat([frames['C'], frames['E']], axis=1)
df
# Out:
#      Temperature [C]  Time [Year]
# 0           0.690380  1994.731517
# 1           0.216873  1995.152620
# 2           0.047806  1989.504769
# 3           0.252496  1995.540270
# 4          -0.412653  1994.065041
# ..               ...          ...
# 995         3.387781  2003.133482
# 996         3.623005  2007.268241
# 997         2.725456  2005.949991
# 998         4.891236  2003.224782
# 999         2.989557  2006.501412
#
# [1000 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=df, x='Temperature [C]', y='Time [Year]')
# Out:
# <Axes: xlabel='Temperature [C]', ylabel='Time [Year]'>
